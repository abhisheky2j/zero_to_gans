# %% [markdown]
# # Human Protein Multi Label Image Classification - Transfer Learning & Regularization
#
#
# How a CNN learns ([source](https://developer.nvidia.com/discover/convolutional-neural-network)):
#
# ![cnn-learning](https://developer.nvidia.com/sites/default/files/pictures/2018/convolutional_neural_network.png)
#
# Layer visualization ([source](https://medium.com/analytics-vidhya/deep-learning-visualization-and-interpretation-of-neural-networks-2f3f82f501c5)):
#
# ![cnn-learning](https://miro.medium.com/max/1610/1*WysCJ6Ynecvviwctt6WDlQ.png)
#
#
# Transfer learning ([source](https://mc.ai/transfer-learning-with-deep-learning-machine-learning-techniques/)):
# ![transfer-learning](https://miro.medium.com/max/1000/1*LUFUl_8fqS97nUzpcFjgWw.png)
#
# This is a starter notebook for the competition [Zero to GANs - Human Protein Classification](https://www.kaggle.com/c/jovian-pytorch-z2g). It incorporates transfer learning, and other techniques from https://jovian.ml/aakashns/05b-cifar10-resnet

# %%
# !pip install git+https://github.com/Kaggle/kaggle-api.git --upgrade
import os
credentials = {"username":"depplenny","key":"c218b6c8a3963c58f9e99de7a89ec338"}
os.environ['KAGGLE_USERNAME']=credentials["username"]
os.environ['KAGGLE_KEY']=credentials["key"]
# !kaggle competitions download -c jovian-pytorch-z2g
# !unzip jovian-pytorch-z2g.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Human protein atlas/train/3069.png
#   inflating: Human protein atlas/train/30690.png
#   inflating: Human protein atlas/train/30691.png
#   inflating: Human protein atlas/train/30692.png
#   inflating: Human protein atlas/train/30693.png
#   inflating: Human protein atlas/train/30694.png
#   inflating: Human protein atlas/train/30696.png
#   inflating: Human protein atlas/train/30697.png
#   inflating: Human protein atlas/train/30698.png
#   inflating: Human protein atlas/train/30699.png
#   inflating: Human protein atlas/train/307.png
#   inflating: Human protein atlas/train/3070.png
#   inflating: Human protein atlas/train/30700.png
#   inflating: Human protein atlas/train/30701.png
#   inflating: Human protein atlas/train/30702.png
#   inflating: Human protein atlas/train/30704.png
#   inflating: Human protein atlas/train/30706.png
#   inflating: Human protein atlas/train/30707.png
#   inflating: Human protein atlas/train/30708.png
#   inflating: Human protein atlas/train/30709.png
#   inflating: Human protein atlas/train/3071.png
#   inflating: Human protein atlas/train/30710.png
#   inflating: Human protein atlas/train/30711.png
#   inflating: Human protein atlas/train/30713.png
#   inflating: Human protein atlas/train/30715.png
#   inflating: Human protein atlas/train/30716.png
#   inflating: Human protein atlas/train/30718.png
#   inflating: Human protein atlas/train/3072.png
#   inflating: Human protein atlas/train/30720.png
#   inflating: Human protein atlas/train/30721.png
#   inflating: Human protein atlas/train/30722.png
#   inflating: Human protein atlas/train/30723.png
#   inflating: Human protein atlas/train/30724.png
#   inflating: Human protein atlas/train/30726.png
#   inflating: Human protein atlas/train/30729.png
#   inflating: Human protein atlas/train/3073.png
#   inflating: Human protein atlas/train/30730.png
#   inflating: Human protein atlas/train/30732.png
#   inflating: Human protein atlas/train/30734.png
#   inflating: Human protein atlas/train/30736.png
#   inflating: Human protein atlas/train/30738.png
#   inflating: Human protein atlas/train/3074.png
#   inflating: Human protein atlas/train/30740.png
#   inflating: Human protein atlas/train/30741.png
#   inflating: Human protein atlas/train/30742.png
#   inflating: Human protein atlas/train/30743.png
#   inflating: Human protein atlas/train/30744.png
#   inflating: Human protein atlas/train/30745.png
#   inflating: Human protein atlas/train/30747.png
#   inflating: Human protein atlas/train/30748.png
#   inflating: Human protein atlas/train/30749.png
#   inflating: Human protein atlas/train/3075.png
#   inflating: Human protein atlas/train/30751.png
#   inflating: Human protein atlas/train/30752.png
#   inflating: Human protein atlas/train/30754.png
#   inflating: Human protein atlas/train/30756.png
#   inflating: Human protein atlas/train/30757.png
#   inflating: Human protein atlas/train/30758.png
#   inflating: Human protein atlas/train/30759.png
#   inflating: Human protein atlas/train/30761.png
#   inflating: Human protein atlas/train/30762.png
#   inflating: Human protein atlas/train/30763.png
#   inflating: Human protein atlas/train/30765.png
#   inflating: Human protein atlas/train/30769.png
#   inflating: Human protein atlas/train/3077.png
#   inflating: Human protein atlas/train/30770.png
#   inflating: Human protein atlas/train/30771.png
#   inflating: Human protein atlas/train/30774.png
#   inflating: Human protein atlas/train/30777.png
#   inflating: Human protein atlas/train/30778.png
#   inflating: Human protein atlas/train/30779.png
#   inflating: Human protein atlas/train/30780.png
#   inflating: Human protein atlas/train/30781.png
#   inflating: Human protein atlas/train/30785.png
#   inflating: Human protein atlas/train/30786.png
#   inflating: Human protein atlas/train/30788.png
#   inflating: Human protein atlas/train/30789.png
#   inflating: Human protein atlas/train/3079.png
#   inflating: Human protein atlas/train/30792.png
#   inflating: Human protein atlas/train/30793.png
#   inflating: Human protein atlas/train/30794.png
#   inflating: Human protein atlas/train/30797.png
#   inflating: Human protein atlas/train/308.png
#   inflating: Human protein atlas/train/30800.png
#   inflating: Human protein atlas/train/30801.png
#   inflating: Human protein atlas/train/30802.png
#   inflating: Human protein atlas/train/30804.png
#   inflating: Human protein atlas/train/30806.png
#   inflating: Human protein atlas/train/30807.png
#   inflating: Human protein atlas/train/30811.png
#   inflating: Human protein atlas/train/30813.png
#   inflating: Human protein atlas/train/30814.png
#   inflating: Human protein atlas/train/30815.png
#   inflating: Human protein atlas/train/30817.png
#   inflating: Human protein atlas/train/30818.png
#   inflating: Human protein atlas/train/30819.png
#   inflating: Human protein atlas/train/3082.png
#   inflating: Human protein atlas/train/30821.png
#   inflating: Human protein atlas/train/30822.png
#   inflating: Human protein atlas/train/30823.png
#   inflating: Human protein atlas/train/30824.png
#   inflating: Human protein atlas/train/30825.png
#   inflating: Human protein atlas/train/30829.png
#   inflating: Human protein atlas/train/3083.png
#   inflating: Human protein atlas/train/30830.png
#   inflating: Human protein atlas/train/30831.png
#   inflating: Human protein atlas/train/30832.png
#   inflating: Human protein atlas/train/30833.png
#   inflating: Human protein atlas/train/30835.png
#   inflating: Human protein atlas/train/30836.png
#   inflating: Human protein atlas/train/30837.png
#   inflating: Human protein atlas/train/30838.png
#   inflating: Human protein atlas/train/30839.png
#   inflating: Human protein atlas/train/3084.png
#   inflating: Human protein atlas/train/30840.png
#   inflating: Human protein atlas/train/30841.png
#   inflating: Human protein atlas/train/30842.png
#   inflating: Human protein atlas/train/30845.png
#   inflating: Human protein atlas/train/30848.png
#   inflating: Human protein atlas/train/9826.png
#   inflating: Human protein atlas/train/9828.png
#   inflating: Human protein atlas/train/9829.png
#   inflating: Human protein atlas/train/9830.png
#   inflating: Human protein atlas/train/9831.png
#   inflating: Human protein atlas/train/9832.png
#   inflating: Human protein atlas/train/9834.png
#   inflating: Human protein atlas/train/9836.png
#   inflating: Human protein atlas/train/9837.png
#   inflating: Human protein atlas/train/9838.png
#   inflating: Human protein atlas/train/9839.png
#   inflating: Human protein atlas/train/984.png
#   inflating: Human protein atlas/train/9841.png
#   inflating: Human protein atlas/train/9842.png
#   inflating: Human protein atlas/train/9843.png
#   inflating: Human protein atlas/train/9844.png
#   inflating: Human protein atlas/train/9845.png
#   inflating: Human protein atlas/train/9846.png
#   inflating: Human protein atlas/train/9849.png
#   inflating: Human protein atlas/train/985.png
#   inflating: Human protein atlas/train/9851.png
#   inflating: Human protein atlas/train/9853.png
#   inflating: Human protein atlas/train/9854.png
#   inflating: Human protein atlas/train/9855.png
#   inflating: Human protein atlas/train/9856.png
#   inflating: Human protein atlas/train/9858.png
#   inflating: Human protein atlas/train/9860.png
#   inflating: Human protein atlas/train/9862.png
#   inflating: Human protein atlas/train/9863.png
#   inflating: Human protein atlas/train/9866.png
#   inflating: Human protein atlas/train/9869.png
#   inflating: Human protein atlas/train/987.png
#   inflating: Human protein atlas/train/9870.png
#   inflating: Human protein atlas/train/9874.png
#   inflating: Human protein atlas/train/9875.png
#   inflating: Human protein atlas/train/9876.png
#   inflating: Human protein atlas/train/9877.png
#   inflating: Human protein atlas/train/9878.png
#   inflating: Human protein atlas/train/9879.png
#   inflating: Human protein atlas/train/9881.png
#   inflating: Human protein atlas/train/9882.png
#   inflating: Human protein atlas/train/9884.png
#   inflating: Human protein atlas/train/9886.png
#   inflating: Human protein atlas/train/9888.png
#   inflating: Human protein atlas/train/989.png
#   inflating: Human protein atlas/train/9891.png
#   inflating: Human protein atlas/train/9892.png
#   inflating: Human protein atlas/train/9893.png
#   inflating: Human protein atlas/train/9894.png
#   inflating: Human protein atlas/train/9895.png
#   inflating: Human protein atlas/train/9898.png
#   inflating: Human protein atlas/train/9899.png
#   inflating: Human protein atlas/train/990.png
#   inflating: Human protein atlas/train/9901.png
#   inflating: Human protein atlas/train/9902.png
#   inflating: Human protein atlas/train/9903.png
#   inflating: Human protein atlas/train/9904.png
#   inflating: Human protein atlas/train/9906.png
#   inflating: Human protein atlas/train/9909.png
#   inflating: Human protein atlas/train/9910.png
#   inflating: Human protein atlas/train/9913.png
#   inflating: Human protein atlas/train/9914.png
#   inflating: Human protein atlas/train/9915.png
#   inflating: Human protein atlas/train/9919.png
#   inflating: Human protein atlas/train/9920.png
#   inflating: Human protein atlas/train/9921.png
#   inflating: Human protein atlas/train/9923.png
#   inflating: Human protein atlas/train/9928.png
#   inflating: Human protein atlas/train/9935.png
#   inflating: Human protein atlas/train/9937.png
#   inflating: Human protein atlas/train/9938.png
#   inflating: Human protein atlas/train/994.png
#   inflating: Human protein atlas/train/9941.png
#   inflating: Human protein atlas/train/9943.png
#   inflating: Human protein atlas/train/9944.png
#   inflating: Human protein atlas/train/9946.png
#   inflating: Human protein atlas/train/9948.png
#   inflating: Human protein atlas/train/9949.png
#   inflating: Human protein atlas/train/995.png
#   inflating: Human protein atlas/train/9951.png
#   inflating: Human protein atlas/train/9954.png
#   inflating: Human protein atlas/train/9957.png
#   inflating: Human protein atlas/train/9958.png
#   inflating: Human protein atlas/train/996.png
#   inflating: Human protein atlas/train/9960.png
#   inflating: Human protein atlas/train/9961.png
#   inflating: Human protein atlas/train/9963.png
#   inflating: Human protein atlas/train/9965.png
#   inflating: Human protein atlas/train/9966.png
#   inflating: Human protein atlas/train/9967.png
#   inflating: Human protein atlas/train/9968.png
#   inflating: Human protein atlas/train/9969.png
#   inflating: Human protein atlas/train/997.png
#   inflating: Human protein atlas/train/9971.png
#   inflating: Human protein atlas/train/9972.png
#   inflating: Human protein atlas/train/9974.png
#   inflating: Human protein atlas/train/9975.png
#   inflating: Human protein atlas/train/9977.png
#   inflating: Human protein atlas/train/9978.png
#   inflating: Human protein atlas/train/9979.png
#   inflating: Human protein atlas/train/998.png
#   inflating: Human protein atlas/train/9981.png
#   inflating: Human protein atlas/train/9985.png
#   inflating: Human protein atlas/train/9986.png
#   inflating: Human protein atlas/train/9987.png
#   inflating: Human protein atlas/train/9988.png
#   inflating: Human protein atlas/train/999.png
#   inflating: Human protein atlas/train/9990.png
#   inflating: Human protein atlas/train/9991.png
#   inflating: Human protein atlas/train/9992.png
#   inflating: Human protein atlas/train/9993.png
#   inflating: Human protein atlas/train/9995.png
#   inflating: Human protein atlas/train/9999.png
#   inflating: submission.csv

# %%
DATA_DIR = '/content/Human protein atlas'

TRAIN_DIR = DATA_DIR + '/train'                           # Contains training images
TEST_DIR = DATA_DIR + '/test'                             # Contains test images

TRAIN_CSV = DATA_DIR + '/train.csv'                       # Contains real labels for training images
TEST_CSV = '/content/submission.csv'   # Contains dummy labels for test image

# %%
import os
import torch
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, random_split, DataLoader
from PIL import Image
import torchvision.models as models
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import torchvision.transforms as T
from sklearn.metrics import f1_score
import torch.nn.functional as F
import torch.nn as nn
from torchvision.utils import make_grid
# %matplotlib inline

# %% [markdown]
# ## Preparing the Data

# %%
data_df = pd.read_csv(TRAIN_CSV)
data_df.head()
# Out:
#    Image Label
# 0  19567     9
# 1  29993   6 4
# 2  17186   1 4
# 3  29600   6 2
# 4    701   3 4

# %%
labels = {
    0: 'Mitochondria',
    1: 'Nuclear bodies',
    2: 'Nucleoli',
    3: 'Golgi apparatus',
    4: 'Nucleoplasm',
    5: 'Nucleoli fibrillar center',
    6: 'Cytosol',
    7: 'Plasma membrane',
    8: 'Centrosome',
    9: 'Nuclear speckles'
}

# %%
def encode_label(label):
    target = torch.zeros(10)
    for l in str(label).split(' '):
        target[int(l)] = 1.
    return target

def decode_target(target, text_labels=False, threshold=0.4):
    # change threshold?
    result = []
    for i, x in enumerate(target):
        if (x >= threshold):
            if text_labels:
                result.append(labels[i] + "(" + str(i) + ")")
            else:
                result.append(str(i))
    return ' '.join(result)

# %%
decode_target(encode_label('9 8 1'))
# Out:
# '1 8 9'

# %%
class HumanProteinDataset(Dataset):
    def __init__(self, df, root_dir, transform=None):
        # pandas dataframe
        self.df = df
        self.transform = transform
        self.root_dir = root_dir
        
    def __len__(self):
        return len(self.df)    
    
    def __getitem__(self, idx):
        row = self.df.loc[idx]
        img_id, img_label = row['Image'], row['Label']
        img_fname = self.root_dir + "/" + str(img_id) + ".png"
        img = Image.open(img_fname)
        if self.transform:
            # transform PIL Image
            img = self.transform(img)
        return img, encode_label(img_label)

# %% [markdown]
# ### Data augmentations

# %%
imagenet_stats = ([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])

train_tfms = T.Compose([
    T.RandomCrop(512, padding=8, padding_mode='reflect'),
#     T.RandomResizedCrop(256, scale=(0.5,0.9), ratio=(1, 1)), 
#     T.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),
    T.RandomHorizontalFlip(), 
    T.RandomRotation(10),
    T.ToTensor(), 
#     T.Normalize(*imagenet_stats,inplace=True), 
    T.RandomErasing(inplace=True)
])

valid_tfms = T.Compose([
#     T.Resize(256), 
    T.ToTensor(), 
#     T.Normalize(*imagenet_stats)
])

# %%
np.random.seed(42)
# Take about 2% of train data as validation
msk = np.random.rand(len(data_df)) < 0.98

train_df = data_df[msk].reset_index()
val_df = data_df[~msk].reset_index()

# %%
train_ds = HumanProteinDataset(train_df, TRAIN_DIR, transform=train_tfms)
val_ds = HumanProteinDataset(val_df, TRAIN_DIR, transform=valid_tfms)
len(train_ds), len(val_ds)
# Out:
# (19051, 185)

# %%
def show_sample(img, target, invert=True):
    if invert:
        plt.imshow(1 - img.permute((1, 2, 0)))
    else:
        plt.imshow(img.permute(1, 2, 0))
    print('Labels:', decode_target(target, text_labels=True))

# %%
show_sample(*train_ds[2], invert=False)
# Out:
# Labels: Nuclear bodies(1) Nucleoplasm(4)

# %% [markdown]
# ### DataLoaders

# %%
batch_size = 64

# %%
train_dl = DataLoader(train_ds, batch_size, shuffle=True, 
                      num_workers=3, pin_memory=True)
val_dl = DataLoader(val_ds, batch_size*2, 
                    num_workers=2, pin_memory=True)

# %%
def show_batch(dl, invert=True):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(16, 8))
        ax.set_xticks([]); ax.set_yticks([])
        data = 1-images if invert else images
        ax.imshow(make_grid(data, nrow=16).permute(1, 2, 0))
        break

# %%
show_batch(train_dl, invert=True)

# %% [markdown]
# ## Model - Transfer Learning

# %%
#?
def F_score(output, label, threshold=0.4, beta=1):
    prob = output > threshold
    label = label > threshold

    TP = (prob & label).sum(1).float()
    TN = ((~prob) & (~label)).sum(1).float()
    FP = (prob & (~label)).sum(1).float()
    FN = ((~prob) & label).sum(1).float()

    precision = torch.mean(TP / (TP + FP + 1e-12))
    recall = torch.mean(TP / (TP + FN + 1e-12))
    F2 = (1 + beta**2) * precision * recall / (beta**2 * precision + recall + 1e-12)
    return F2.mean(0)

# %%
class MultilabelImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, targets = batch 
        out = self(images)                      
        loss = F.binary_cross_entropy(out, targets)      
        return loss
    
    def validation_step(self, batch):
        images, targets = batch 
        out = self(images)                           # Generate predictions
        loss = F.binary_cross_entropy(out, targets)  # Calculate loss
        score = F_score(out, targets)
        return {'val_loss': loss.detach(), 'val_score': score.detach() }
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_scores = [x['val_score'] for x in outputs]
        epoch_score = torch.stack(batch_scores).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_score': epoch_score.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.4f}, train_loss: {:.4f}, val_loss: {:.4f}, val_score: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_score']))

# %% [markdown]
# [Learn about ResNets.](https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035)
#
# Check out torchvision models: https://pytorch.org/docs/stable/torchvision/models.html

# %%
models.resnet34()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
class ProteinResnet(MultilabelImageClassificationBase):
    def __init__(self):
        super().__init__()
        # Use a pretrained model
        self.network = models.resnet34(pretrained=True)
        # Replace last layer
        num_ftrs = self.network.fc.in_features
        self.network.fc = nn.Linear(num_ftrs, 10)
    
    def forward(self, xb):
        return torch.sigmoid(self.network(xb))
    
    def freeze(self):
        # To freeze the residual layers
        for param in self.network.parameters():
            param.require_grad = False
        for param in self.network.fc.parameters():
            param.require_grad = True
    
    def unfreeze(self):
        # Unfreeze all layers
        for param in self.network.parameters():
            param.require_grad = True

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)

# %% [markdown]
# ## Training

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit_one_cycle(epochs, max_lr, model, train_loader, val_loader, 
                  weight_decay=0, grad_clip=None, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []
    
    # Set up cutom optimizer with weight decay
    optimizer = opt_func(model.parameters(), max_lr, weight_decay=weight_decay)
    # Set up one-cycle learning rate scheduler
    sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epochs, 
                                                steps_per_epoch=len(train_loader))
    
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        lrs = []
        for batch in tqdm(train_loader):
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            
            # Gradient clipping
            if grad_clip: 
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)
            
            optimizer.step()
            optimizer.zero_grad()
            
            # Record & update learning rate
            lrs.append(get_lr(optimizer))
            sched.step()
        
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        result['lrs'] = lrs
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
model = to_device(ProteinResnet(), device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %%
history = [evaluate(model, val_dl)]
history
# Out:
# [{'val_loss': 0.7348500490188599, 'val_score': 0.26678091287612915}]

# %%
torch.cuda.empty_cache()

# %% [markdown]
# First, freeze the ResNet layers and train some epochs. This only trains the final layer to start classifying the images.

# %%
model.freeze()

# %%
epochs = 20
max_lr = 0.005 # 0.01
grad_clip = 0.1
weight_decay = 1e-4
opt_func = torch.optim.Adam

# %%
# %%time
history += fit_one_cycle(epochs, max_lr, model, train_dl, val_dl, 
                         grad_clip=grad_clip, 
                         weight_decay=weight_decay, 
                         opt_func=opt_func)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [0], last_lr: 0.0028, train_loss: 0.2846, val_loss: 0.4127, val_score: 0.3802
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [1], last_lr: 0.0076, train_loss: 0.2837, val_loss: 0.3470, val_score: 0.4445
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [2], last_lr: 0.0100, train_loss: 0.2867, val_loss: 0.3542, val_score: 0.5057
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [3], last_lr: 0.0095, train_loss: 0.2793, val_loss: 0.4551, val_score: 0.3843
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [4], last_lr: 0.0081, train_loss: 0.2677, val_loss: 0.3288, val_score: 0.5168
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [5], last_lr: 0.0061, train_loss: 0.2587, val_loss: 0.3428, val_score: 0.5405
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [6], last_lr: 0.0039, train_loss: 0.2477, val_loss: 0.2855, val_score: 0.6297
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [7], last_lr: 0.0019, train_loss: 0.2360, val_loss: 0.2651, val_score: 0.6254
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [8], last_lr: 0.0005, train_loss: 0.2245, val_loss: 0.2356, val_score: 0.6934
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [9], last_lr: 0.0000, train_loss: 0.2160, val_loss: 0.2317, val_score: 0.7155
# CPU times: user 14min 47s, sys: 9min 59s, total: 24min 47s
# Wall time: 56min 21s

# %% [markdown]
# Now, unfreeze and train some more.

# %%
# model.unfreeze()

# %%
# %%time
# history += fit_one_cycle(epochs, 0.001, model, train_dl, val_dl, 
                         grad_clip=grad_clip, 
                         weight_decay=weight_decay, 
                         opt_func=opt_func)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [0], last_lr: 0.0003, train_loss: 0.2144, val_loss: 0.2322, val_score: 0.7094
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [1], last_lr: 0.0008, train_loss: 0.2149, val_loss: 0.2336, val_score: 0.7175
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [2], last_lr: 0.0010, train_loss: 0.2145, val_loss: 0.2327, val_score: 0.6796
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [3], last_lr: 0.0010, train_loss: 0.2112, val_loss: 0.2421, val_score: 0.6763
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [4], last_lr: 0.0008, train_loss: 0.2076, val_loss: 0.2363, val_score: 0.6874
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [5], last_lr: 0.0006, train_loss: 0.2038, val_loss: 0.2186, val_score: 0.7106
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [6], last_lr: 0.0004, train_loss: 0.2000, val_loss: 0.2157, val_score: 0.7325
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [7], last_lr: 0.0002, train_loss: 0.1956, val_loss: 0.2084, val_score: 0.7276
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [8], last_lr: 0.0000, train_loss: 0.1925, val_loss: 0.2055, val_score: 0.7241
# HBox(children=(FloatProgress(value=0.0, max=298.0), HTML(value='')))
# Epoch [9], last_lr: 0.0000, train_loss: 0.1911, val_loss: 0.2057, val_score: 0.7315
# CPU times: user 14min 35s, sys: 9min 53s, total: 24min 28s
# Wall time: 55min 24s

# %%
def plot_scores(history):
    scores = [x['val_score'] for x in history]
    plt.plot(scores, '-x')
    plt.xlabel('epoch')
    plt.ylabel('score')
    plt.title('F1 score vs. No. of epochs');

# %%
plot_scores(history)

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');

# %%
plot_losses(history)

# %%
def plot_lrs(history):
    lrs = np.concatenate([x.get('lrs', []) for x in history])
    plt.plot(lrs)
    plt.xlabel('Batch no.')
    plt.ylabel('Learning rate')
    plt.title('Learning Rate vs. Batch no.');

# %%
plot_lrs(history)

# %% [markdown]
# ## Making predictions and submission

# %%
def predict_single(image):
    xb = image.unsqueeze(0)
    xb = to_device(xb, device)
    preds = model(xb)
    prediction = preds[0]
    print("Prediction: ", prediction)
    show_sample(image, prediction)

# %%
test_df = pd.read_csv(TEST_CSV)
test_dataset = HumanProteinDataset(test_df, TEST_DIR, transform=valid_tfms)

# %%
img, target = test_dataset[0]
img.shape
# Out:
# torch.Size([3, 512, 512])

# %%
predict_single(test_dataset[100][0])
# Out:
# Prediction:  tensor([0.0107, 0.0346, 0.0939, 0.0117, 0.9710, 0.0141, 0.9020, 0.0285, 0.0268,
#         0.0049], device='cuda:0', grad_fn=<SelectBackward>)
# Labels: Nucleoplasm(4) Cytosol(6)

# %%
predict_single(test_dataset[74][0])
# Out:
# Prediction:  tensor([9.7424e-01, 4.4137e-03, 5.2425e-03, 9.3739e-02, 5.4070e-02, 1.7151e-03,
#         5.6745e-02, 8.6141e-03, 3.2629e-03, 8.4190e-04], device='cuda:0',
#        grad_fn=<SelectBackward>)
# Labels: Mitochondria(0)

# %%
test_dl = DeviceDataLoader(DataLoader(test_dataset, batch_size, num_workers=3, pin_memory=True), device)

# %%
@torch.no_grad()
def predict_dl(dl, model):
    torch.cuda.empty_cache()
    batch_probs = []
    for xb, _ in tqdm(dl):
        probs = model(xb)
        batch_probs.append(probs.cpu().detach())
    batch_probs = torch.cat(batch_probs)
    return [decode_target(x) for x in batch_probs]

# %%
test_preds = predict_dl(test_dl, model)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=129.0), HTML(value='')))

# %%
submission_df = pd.read_csv(TEST_CSV)
submission_df.Label = test_preds
submission_df.sample(20)
# Out:
#       Image  Label
# 5168  27233
# 6336  26023      4
# 5962   2884    4 6
# 6513  27639      9
# 5100  12658      8
# 5971  24299    2 6
# 4931  23286    4 6
# 1     15322      4
# 5122   6801      4
# 6285   7597    3 4
# 6575  28143  2 4 6
# 1905  11311      0
# 4214  23863    1 8
# 40    18332      9
# 149   11145      9
# 64     7711  2 4 6
# 8073   6293      7
# 1359  14049      1
# 5461   9590      3
# 4505  14696      1

# %%
sub_fname = 'submission.csv'

# %%
submission_df.to_csv(sub_fname, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a4c98505d34d> in <module>
# ----> 1 submission_df.to_csv(sub_fname, index=False)
#
# NameError: name 'submission_df' is not defined

# %%
weights_fname = 'protein-resnet.pth'
torch.save(model.state_dict(), weights_fname)
